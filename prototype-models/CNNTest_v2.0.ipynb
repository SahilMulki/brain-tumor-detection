# %%
# %pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (2.21.0)
# Requirement already satisfied: opencv-python in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (4.13.0.92)
# Requirement already satisfied: matplotlib in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (3.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: keras>=3.12.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (3.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=9 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
import numpy as np
import os
import cv2
from matplotlib import pyplot as plt

# %%
train_data = tf.keras.utils.image_dataset_from_directory('brain_mri_dataset/Training')
# Out:
# Found 5600 files belonging to 4 classes.

# %%
from collections import Counter

labels = []
for _, y in train_data.unbatch():
    labels.append(y.numpy())

counts = Counter(labels)
for i, name in enumerate(train_data.class_names):
    print(f"{name}: {counts[i]}")
# Out:
# glioma: 1400
# meningioma: 1400
# notumor: 1400
# pituitary: 1400

# %%
data_iterator = train_data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
class_names = train_data.class_names
fig, ax = plt.subplots(ncols = 4, figsize = (20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(class_names[batch[1][idx]])

# %%
train_data = train_data.map(lambda x,y: (x/255, y))

# %%
scaled = train_data.as_numpy_iterator().next()

# %%
scaled[0].max()
# Out:
# np.float32(1.0)

# %%
tf.random.set_seed(42)

train_data = train_data.shuffle(buffer_size=len(train_data), seed=42, reshuffle_each_iteration=False)

train_size = int(len(train_data) * 0.8)
val_size = len(train_data) - train_size
train = train_data.take(train_size)
val = train_data.skip(train_size)

# %%
test_data = tf.keras.utils.image_dataset_from_directory('brain_mri_dataset/Testing')
test_data = test_data.map(lambda x, y: (x/255, y))
# Out:
# Found 1600 files belonging to 4 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

model.add(Conv2D(16, (3,3), 1, activation ='relu', input_shape = (256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3,3), 1, activation ='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), 1, activation ='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Conv2D(128, (3,3), 1, activation ='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(256, activation ='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation ='softmax'))
# Out:
# C:\Users\miken\OneDrive\Desktop\brain-tumor-detection\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile('adam', loss = tf.losses.SparseCategoricalCrossentropy(), metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       6,422,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,521,252 (24.88 MB)
#  Trainable params: 6,521,252 (24.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

# %%
hist = model.fit(train, epochs = 20, validation_data = val, callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/20
# C:\Users\miken\OneDrive\Desktop\brain-tumor-detection\venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 53s 350ms/step - accuracy: 0.5904 - loss: 0.9822 - val_accuracy: 0.7598 - val_loss: 0.6037
# Epoch 2/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 71s 487ms/step - accuracy: 0.7812 - loss: 0.5679 - val_accuracy: 0.8232 - val_loss: 0.4633
# Epoch 3/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 71s 481ms/step - accuracy: 0.8257 - loss: 0.4615 - val_accuracy: 0.8616 - val_loss: 0.3584
# Epoch 4/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 70s 479ms/step - accuracy: 0.8473 - loss: 0.4051 - val_accuracy: 0.8920 - val_loss: 0.2969
# Epoch 5/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 71s 482ms/step - accuracy: 0.8730 - loss: 0.3315 - val_accuracy: 0.9116 - val_loss: 0.2501
# Epoch 6/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 509ms/step - accuracy: 0.8933 - loss: 0.2775 - val_accuracy: 0.8920 - val_loss: 0.2664
# Epoch 7/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 494ms/step - accuracy: 0.9123 - loss: 0.2402 - val_accuracy: 0.9464 - val_loss: 0.1617
# Epoch 8/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 72s 488ms/step - accuracy: 0.9217 - loss: 0.2152 - val_accuracy: 0.9598 - val_loss: 0.1321
# Epoch 9/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 505ms/step - accuracy: 0.9328 - loss: 0.1829 - val_accuracy: 0.9732 - val_loss: 0.0889
# Epoch 10/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 78s 528ms/step - accuracy: 0.9433 - loss: 0.1504 - val_accuracy: 0.9732 - val_loss: 0.0720
# Epoch 11/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 520ms/step - accuracy: 0.9525 - loss: 0.1318 - val_accuracy: 0.9839 - val_loss: 0.0579
# Epoch 12/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 79s 537ms/step - accuracy: 0.9542 - loss: 0.1210 - val_accuracy: 0.9759 - val_loss: 0.0712
# Epoch 13/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 74s 501ms/step - accuracy: 0.9571 - loss: 0.1150 - val_accuracy: 0.9768 - val_loss: 0.0621
# Epoch 14/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 80s 491ms/step - accuracy: 0.9652 - loss: 0.0973 - val_accuracy: 0.9893 - val_loss: 0.0427
# Epoch 15/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 496ms/step - accuracy: 0.9674 - loss: 0.0942 - val_accuracy: 0.9911 - val_loss: 0.0323
# Epoch 16/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 76s 517ms/step - accuracy: 0.9759 - loss: 0.0666 - val_accuracy: 0.9902 - val_loss: 0.0314
# Epoch 17/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 73s 497ms/step - accuracy: 0.9699 - loss: 0.0807 - val_accuracy: 0.9920 - val_loss: 0.0245
# Epoch 18/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 39s 257ms/step - accuracy: 0.9688 - loss: 0.0808 - val_accuracy: 0.9893 - val_loss: 0.0294
# Epoch 19/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 37s 252ms/step - accuracy: 0.9701 - loss: 0.0814 - val_accuracy: 0.9973 - val_loss: 0.0163
# Epoch 20/20
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 36s 246ms/step - accuracy: 0.9783 - loss: 0.0652 - val_accuracy: 0.9964 - val_loss: 0.0110

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color = 'red', label = 'loss')
plt.plot(hist.history['val_loss'], color = 'blue', label = 'val_loss')
fig.suptitle('Loss', fontsize = 20)
plt.legend(loc = "upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color = 'green', label = 'accuracy')
plt.plot(hist.history['val_accuracy'], color = 'blue', label = 'val_accuracy')
fig.suptitle('ACC', fontsize = 20)
plt.legend(loc = "upper left")
plt.show()

# %%
model.evaluate(test_data)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9031 - loss: 0.9352
# [0.9351662993431091, 0.903124988079071]

# %%
# %pip install scikit-learn seaborn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (1.9.0)
# Requirement already satisfied: seaborn in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from scikit-learn) (2.5.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\miken\onedrive\desktop\brain-tumor-detection\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

y_true = []
y_pred = []
for x, y in test_data:
    preds = model.predict(x, verbose=0)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(y.numpy())

print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.94      0.73      0.82       400
#   meningioma       0.85      0.92      0.88       400
#      notumor       0.87      1.00      0.93       400
#    pituitary       0.97      0.97      0.97       400
#
#     accuracy                           0.90      1600
#    macro avg       0.91      0.90      0.90      1600
# weighted avg       0.91      0.90      0.90      1600

# %%
model.save('CNNTest_v2.0.keras')
